# %% [markdown]
# # Three Body Work-Precision Diagrams

# %% [markdown]
# ##  Based on
# https://github.com/JuliaDiffEq/DiffEqBenchmarks.jl/blob/master/notebook/NonStiffODE/ThreeBody_wpd.ipynb

# %%
using Pkg
using OrdinaryDiffEq,IRK,Plots,DiffEqDevTools

# %% [markdown]
# ## Define the ThreeBody Problem

# %%
const threebody_μ = parse(Float64,"0.012277471")
const threebody_μ′ = 1 - threebody_μ

f = (du,u,p,t) -> begin
  @inbounds begin
  # 1 = y₁
  # 2 = y₂
  # 3 = y₁'
  # 4 = y₂'
  D₁ = ((u[1]+threebody_μ)^2 + u[2]^2)^(3/2)
  D₂ = ((u[1]-threebody_μ′)^2 + u[2]^2)^(3/2)
  du[1] = u[3]
  du[2] = u[4]
  du[3] = u[1] + 2u[4] - threebody_μ′*(u[1]+threebody_μ)/D₁ - threebody_μ*(u[1]-threebody_μ′)/D₂
  du[4] = u[2] - 2u[3] - threebody_μ′*u[2]/D₁ - threebody_μ*u[2]/D₂
  end
end

t₀ = 0.0; T = parse(Float64,"17.0652165601579625588917206249")
tspan = (t₀,2T)

prob = ODEProblem(f,[0.994, 0.0, 0.0, parse(Float64,"-2.00158510637908252240537862224")],tspan)

test_sol = TestSolution(T,[prob.u0])
abstols = 1.0 ./ 10.0 .^ (3:13); reltols = 1.0 ./ 10.0 .^ (0:10);

# %% [markdown]
# See that it's periodic in the chosen timespan:

# %%
sol = solve(prob,Vern9(),abstol=1e-14,reltol=1e-14)
@show sol[1] - sol[end]
@show sol[end] - prob.u0;
# Out:
# sol[1] - sol[end] = [-2.7379654099490836e-11, -8.161904230816544e-11, -1.3315526556367807e-8, -4.261521802106927e-9]
# sol[end] - prob.u0 = [2.7379654099490836e-11, 8.161904230816544e-11, 1.3315526556367807e-8, 4.261521802106927e-9]

# %%
apr = appxtrue(sol,test_sol)
@show sol[end]
@show apr.u[end]
@show apr.errors
# Out:
# sol[end] = [0.9940000000273796, 8.161904230816544e-11, 1.3315526556367807e-8, -2.0015851021175606]
# apr.u[end] = [0.9940000000273796, 8.161904230816544e-11, 1.3315526556367807e-8, -2.0015851021175606]
# apr.errors = Dict(:final => 4.4215117637205975e-9)
# Dict{Symbol,Float64} with 1 entry:
#   :final => 4.42151e-9

# %% [markdown]
# ## IRK8 Fixed-Step

# %%
n=10000
dt=(tspan[2]-tspan[1])/n
(sol1,iters) = @time(solve(prob,IRK8(),dt=dt,saveat=10*dt,
                           adaptive=false,myoutputs=true));
# Out:
#   6.272856 seconds (21.00 M allocations: 764.777 MiB, 8.28% gc time)

# %%
@show dt
@show length(sol1.t)
@show sol1[1] - sol1[end]
# Out:
# dt = 0.003413043312031593
# length(sol1.t) = 1001
# sol1[1] - sol1[end] = [-9.479300455694784e-9, -2.8136431658207892e-8, -4.590875062451143e-6, -1.475433982989216e-6]
# 4-element Array{Float64,1}:
#  -9.479300455694784e-9
#  -2.8136431658207892e-8
#  -4.590875062451143e-6
#  -1.475433982989216e-6

# %%
plot(sol1,vars=(1,2))

# %% [markdown]
# ## IRK8 Adaptive-Step

# %%
n=10000
dt=(tspan[2]-tspan[1])/n
(sol2,iters2,steps2,rejects2) = @time(solve(prob,IRK8(),dt=dt,reltol=1e-12, abstol=1e-12,
                                      adaptive=true,myoutputs=true));
# Out:
#   0.031241 seconds (1.25 M allocations: 33.626 MiB)

# %%
@show length(sol2.t)
@show sol2[1] - sol2[end]
# Out:
# length(sol2.t) = 171
# sol2[1] - sol2[end] = [4.5809911419780747e-11, 1.3593954075540146e-10, 2.2180751516402664e-8, 7.13016312658965e-9]
# 4-element Array{Float64,1}:
#  4.5809911419780747e-11
#  1.3593954075540146e-10
#  2.2180751516402664e-8
#  7.13016312658965e-9

# %%
plot(sol2.t,steps2, title="step sizes in the integration", legend=false)

# %%
plot(sol1,vars=(1,2))

# %%
apr = appxtrue(sol2,test_sol)
@show sol2[end]
@show apr.u[end]
@show apr.errors
# Out:
# sol2[end] = [0.9939999999541901, -1.3593954075540146e-10, -2.2180751516402664e-8, -2.0015851135092455]
# apr.u[end] = [0.9939999999541901, -1.3593954075540146e-10, -2.2180751516402664e-8, -2.0015851135092455]
# apr.errors = Dict(:final => 7.373166023791874e-9)
# Dict{Symbol,Float64} with 1 entry:
#   :final => 7.37317e-9

# %% [markdown]
# ## Higher Order Algorithms

# %%
setups = [Dict(:alg=>DP5())
          Dict(:alg=>Vern7())
          Dict(:alg=>Vern8())
          Dict(:alg=>DP8())
#          Dict(:alg=>IRK8())   # fail
          Dict(:alg=>Vern9())];
wp = WorkPrecisionSet(prob,abstols,reltols,setups;appxsol=test_sol,save_everystep=false,numruns=100)
plot(wp)
# Out:
# Fixed timestep methods require a choice of dt or choosing the tstops
#
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] #__init#329(::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Nothing, ::Bool, ::Bool, ::Bool, ::Bool, ::Nothing, ::Bool, ::Bool, ::Float64, ::Float64, ::Float64, ::Bool, ::Bool, ::Rational{Int64}, ::Float64, ::Float64, ::Rational{Int64}, ::Int64, ::Int64, ::Int64, ::Rational{Int64}, ::Bool, ::Int64, ::Nothing, ::Nothing, ::Int64, ::typeof(DiffEqBase.ODE_DEFAULT_NORM), ::typeof(LinearAlgebra.opnorm), ::typeof(DiffEqBase.ODE_DEFAULT_ISOUTOFDOMAIN), ::typeof(DiffEqBase.ODE_DEFAULT_UNSTABLE_CHECK), ::Bool, ::Bool, ::Bool, ::Bool, ::Bool, ::Bool, ::Bool, ::Int64, ::String, ::typeof(DiffEqBase.ODE_DEFAULT_PROG_MESSAGE), ::Nothing, ::Bool, ::Bool, ::Bool, ::Bool, ::Base.Iterators.Pairs{Symbol,IRK8,Tuple{Symbol},NamedTuple{(:alg,),Tuple{IRK8}}}, ::typeof(DiffEqBase.__init), ::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,var"#5#6",LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem}, ::IRK8, ::Array{Any,1}, ::Array{Any,1}, ::Nothing, ::Type{Val{true}}) at /home/joseba/.julia/packages/OrdinaryDiffEq/8Pn99/src/solve.jl:98
#  [3] (::DiffEqBase.var"#kw##__init")(::NamedTuple{(:abstol, :reltol, :timeseries_errors, :dense_errors, :save_everystep, :alg),Tuple{Float64,Float64,Bool,Bool,Bool,IRK8}}, ::typeof(DiffEqBase.__init), ::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,var"#5#6",LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem}, ::IRK8, ::Array{Any,1}, ::Array{Any,1}, ::Nothing, ::Type{Val{true}}) at ./none:0 (repeats 2 times)
#  [4] #__solve#328(::Base.Iterators.Pairs{Symbol,Any,NTuple{6,Symbol},NamedTuple{(:abstol, :reltol, :timeseries_errors, :dense_errors, :save_everystep, :alg),Tuple{Float64,Float64,Bool,Bool,Bool,IRK8}}}, ::typeof(DiffEqBase.__solve), ::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,var"#5#6",LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem}, ::IRK8, ::Array{Any,1}, ::Vararg{Any,N} where N) at /home/joseba/.julia/packages/OrdinaryDiffEq/8Pn99/src/solve.jl:4
#  [5] (::DiffEqBase.var"#kw##__solve")(::NamedTuple{(:abstol, :reltol, :timeseries_errors, :dense_errors, :save_everystep, :alg),Tuple{Float64,Float64,Bool,Bool,Bool,IRK8}}, ::typeof(DiffEqBase.__solve), ::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,var"#5#6",LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem}, ::IRK8, ::Array{Any,1}, ::Array{Any,1}, ::Vararg{Any,N} where N) at ./none:0
#  [6] #solve_call#442(::Base.Iterators.Pairs{Symbol,Any,NTuple{6,Symbol},NamedTuple{(:abstol, :reltol, :timeseries_errors, :dense_errors, :save_everystep, :alg),Tuple{Float64,Float64,Bool,Bool,Bool,IRK8}}}, ::typeof(DiffEqBase.solve_call), ::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,var"#5#6",LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem}, ::IRK8, ::Vararg{Any,N} where N) at /home/joseba/.julia/packages/DiffEqBase/43aNw/src/solve.jl:0
#  [7] (::DiffEqBase.var"#kw##solve_call")(::NamedTuple{(:abstol, :reltol, :timeseries_errors, :dense_errors, :save_everystep, :alg),Tuple{Float64,Float64,Bool,Bool,Bool,IRK8}}, ::typeof(DiffEqBase.solve_call), ::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,var"#5#6",LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem}, ::IRK8, ::Vararg{Any,N} where N) at ./none:0
#  [8] #solve#443(::Base.Iterators.Pairs{Symbol,Any,NTuple{6,Symbol},NamedTuple{(:abstol, :reltol, :timeseries_errors, :dense_errors, :save_everystep, :alg),Tuple{Float64,Float64,Bool,Bool,Bool,IRK8}}}, ::typeof(solve), ::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,var"#5#6",LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem}, ::IRK8, ::Vararg{Any,N} where N) at /home/joseba/.julia/packages/DiffEqBase/43aNw/src/solve.jl:57
#  [9] (::DiffEqBase.var"#kw##solve")(::NamedTuple{(:abstol, :reltol, :timeseries_errors, :dense_errors, :save_everystep, :alg),Tuple{Float64,Float64,Bool,Bool,Bool,IRK8}}, ::typeof(solve), ::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,var"#5#6",LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem}, ::IRK8, ::Array{Any,1}, ::Vararg{Any,N} where N) at ./none:0
#  [10] macro expansion at ./util.jl:212 [inlined]
#  [11] (::DiffEqDevTools.var"#16#19"{Int64,ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,var"#5#6",LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},IRK8,ODESolution{Any,2,Array{Any,1},Nothing,Nothing,Array{Any,1},Nothing,ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,var"#5#6",LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},IRK8,DiffEqBase.LinearInterpolation{Array{Any,1},Array{Any,1}},Nothing},Array{Float64,1},Array{Float64,1},Base.Iterators.Pairs{Symbol,Any,Tuple{Symbol,Symbol},NamedTuple{(:save_everystep, :alg),Tuple{Bool,IRK8}}}})() at /home/joseba/.julia/packages/DiffEqDevTools/weFfG/src/benchmark.jl:207
#  [12] #WorkPrecision#15(::String, ::TestSolution{Float64,2,false,Float64,Array{Array{Float64,1},1},Nothing}, ::Symbol, ::Int64, ::Int64, ::Base.Iterators.Pairs{Symbol,Any,Tuple{Symbol,Symbol},NamedTuple{(:save_everystep, :alg),Tuple{Bool,IRK8}}}, ::Type{WorkPrecision}, ::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,var"#5#6",LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem}, ::IRK8, ::Array{Float64,1}, ::Array{Float64,1}, ::Nothing) at /home/joseba/.julia/packages/DiffEqDevTools/weFfG/src/benchmark.jl:221
#  [13] Type at ./none:0 [inlined] (repeats 2 times)
#  [14] #WorkPrecisionSet#22(::Bool, ::Nothing, ::TestSolution{Float64,2,false,Float64,Array{Array{Float64,1},1},Nothing}, ::Symbol, ::Nothing, ::Base.Iterators.Pairs{Symbol,Integer,Tuple{Symbol,Symbol},NamedTuple{(:save_everystep, :numruns),Tuple{Bool,Int64}}}, ::Type{WorkPrecisionSet}, ::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,var"#5#6",LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Dict{Symbol,V} where V,1}) at /home/joseba/.julia/packages/DiffEqDevTools/weFfG/src/benchmark.jl:253
#  [15] (::Core.var"#kw#Type")(::NamedTuple{(:appxsol, :save_everystep, :numruns),Tuple{TestSolution{Float64,2,false,Float64,Array{Array{Float64,1},1},Nothing},Bool,Int64}}, ::Type{WorkPrecisionSet}, ::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,DiffEqBase.NullParameters,ODEFunction{true,var"#5#6",LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Dict{Symbol,V} where V,1}) at ./none:0
#  [16] top-level scope at In[18]:7
