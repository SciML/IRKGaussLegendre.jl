# %% [markdown]
# # Bechmark: Vern9 vs IRKGL16 (Float64)
#
# <ul id="top">
#     <li><a href="#Loading-packages">
#              Loading Packages</a></li>
#
# <li><a href="#Initial-value-problem:-Burrau-problem">
#              Initial value problem: Burrau problem</a></li>
#
# <li><a href="#Integration-with-Vern9">
#              Integration with Vern9</a></li>
#
# <li><a href="#Integration-with-IRKGL16-(Adaptive-step)">
#              Integration with IRKGL16 (Adaptive-step)</a></li>
#
# <li><a href="#Error-in-energy">
#              Error in energy</a></li>
#
# </ul>

# %% [markdown]
# 2020-04-18 Exekuzio berezia
#
# - Maixter=12
# - tol=1e-13

# %% [markdown]
# ## Loading packages

# %%
using Pkg
using IRKGaussLegendre,LinearAlgebra,Plots,Statistics
using OrdinaryDiffEq
using DiffEqDevTools,BenchmarkTools
using Dates

# %%
BenchmarkTools.DEFAULT_PARAMETERS.samples=10
# Out:
# 10

# %% [markdown]
# <a href="#top">Back to the top</a>
#
# ## Initial value problem: ThreeBody problem

# %%
const μ = parse(Float64,"0.012277471")
#const uμ = 1 - μ

f = (du,u,p,t) -> begin
  
  μ=p[1]
  uμ=1-μ
  @inbounds begin
  # 1 = y₁
  # 2 = y₂
  # 3 = y₁'
  # 4 = y₂'
  D₁ = ((u[1]+μ)^2 + u[2]^2)^(3/2)
  D₂ = ((u[1]-uμ)^2 + u[2]^2)^(3/2)
  du[1] = u[3]+u[2]
  du[2] = u[4]-u[1]
  du[3] = u[4] - uμ*(u[1]+μ)/D₁ - μ*(u[1]-uμ)/D₂
  du[4] = -u[3] - uμ*u[2]/D₁ - μ*u[2]/D₂
  end
end


t₀ = 0.0;
T = parse(Float64,"17.0652165601579625588917206249")
tspan = (t₀,2T)

py0=parse(BigFloat,"-2.00158510637908252240537862224")+0.994
u0=[0.994,0.0,0.0, Float64(py0)]
prob = ODEProblem(f,u0,tspan,[μ])
# Out:
# ODEProblem with uType Array{Float64,1} and tType Float64. In-place: true
# timespan: (0.0, 34.13043312031593)
# u0: [0.994, 0.0, 0.0, -1.0075851063790826]

# %% [markdown]
# <a href="#top">Back to the top</a>
#
#
# ## Integration with Vern9

# %% [markdown]
# Recommend methods: Non-Stiff Problems
#
# - For high accuracy non-stiff solving ( BigFloat and tolerances like <1e-12 ), JuliaDiffeq recommend
# the Vern9 method

# %%
sol0 = @time(solve(prob,Vern9(),abstol=1e-13,reltol=1e-13));
# Out:
#  21.579074 seconds (51.92 M allocations: 2.331 GiB, 8.86% gc time)

# %%
sol0.destats
# Out:
# DiffEqBase.DEStats
# Number of function 1 evaluations:                  11330
# Number of function 2 evaluations:                  0
# Number of W matrix evaluations:                    0
# Number of linear solves:                           0
# Number of Jacobians created:                       0
# Number of nonlinear solver iterations:             0
# Number of nonlinear solver convergence failures:   0
# Number of rootfind condition calls:                0
# Number of accepted steps:                          682
# Number of rejected steps:                          26

# %%
plot(sol0,vars=(1,2))

# %% [markdown]
# ## Integration with IRKGL16 (Adaptive-step)

# %%
(sol1,iters1,steps1)=@time(solve(prob,IRKGL16(),  
                          reltol=1e-13, abstol=1e-13,myoutputs=true,initial_interp=true));
# Out:
#   8.504707 seconds (13.11 M allocations: 619.520 MiB, 3.75% gc time)

# %%
sum(iters1)/sol1.destats.naccept
# Out:
# 12.082191780821917

# %%
sol1.destats
# Out:
# DiffEqBase.DEStats
# Number of function 1 evaluations:                  14194
# Number of function 2 evaluations:                  0
# Number of W matrix evaluations:                    0
# Number of linear solves:                           0
# Number of Jacobians created:                       0
# Number of nonlinear solver iterations:             0
# Number of nonlinear solver convergence failures:   0
# Number of rootfind condition calls:                0
# Number of accepted steps:                          146
# Number of rejected steps:                          21

# %% [markdown]
# ## Integration with IRKGL162 (Adaptive-step)

# %%
(sol2,iters2,steps2)=@time(solve(prob,IRKGL162(),  
                          reltol=1e-13, abstol=1e-13,myoutputs=true,initial_interp=true));
# Out:
#   2.089204 seconds (1.55 M allocations: 72.782 MiB, 3.32% gc time)

# %%
sum(iters2)/sol2.destats.naccept
# Out:
# 13.061643835616438

# %%
sol2.destats
# Out:
# DiffEqBase.DEStats
# Number of function 1 evaluations:                  15149
# Number of function 2 evaluations:                  0
# Number of W matrix evaluations:                    0
# Number of linear solves:                           0
# Number of Jacobians created:                       0
# Number of nonlinear solver iterations:             0
# Number of nonlinear solver convergence failures:   0
# Number of rootfind condition calls:                0
# Number of accepted steps:                          146
# Number of rejected steps:                          21

# %% [markdown]
# ### Plots IRKGL16

# %%
plot(sol1.t[2:end],iters1[2:end], title="Iteration numbers", label="IRKGL16")
plot!(sol2.t[2:end],iters2[2:end],label="IRKGL162")

# %%
plot(sol1.t,steps1, title="step sizes in the integration", label="IRKGL16")
plot!(sol2.t,steps2,label="IRKGL162")

# %%
plot(sol1,vars=(1,2))

# %% [markdown]
# <a href="#top">Back to the top</a>

# %% [markdown]
# ## Error in energy

# %%
setprecision(BigFloat, 256)
u0128=[0.994,0.0,0.0, py0]
μ128 = parse(BigFloat,"0.012277471")
(typeof(u0128))
# Out:
# Array{BigFloat,1}

# %%
function NbodyEnergy(u, mu)
"""    
     3RT-Nbody problem      
"""    
    
    # Implementation

 @inbounds begin
    x = u[1]   # x
    y = u[2]   # y
    px = u[3]  # px
    py = u[4]  # py
        
    umu=1-mu    
 
    r1 = ((x+mu)^2 + y^2)^(1/2)
    r2 = ((x-umu)^2 + y^2)^(1/2)
        
    Energy=(px*px+py*py)/2+px*y-py*x-umu/r1-mu/r2-mu*umu/2    

    
    return(Energy)
    end
        
end
# Out:
# NbodyEnergy (generic function with 1 method)

# %%
E0=NbodyEnergy(u0128,μ128)
end1=length(steps1)

ulist = sol0.u
tlist = sol0.t
EnergyErrors=[NbodyEnergy(BigFloat.(sol0.u[j]),μ128)/E0-1 for j in 1:length(tlist)]

ulist1 = sol1.u[1:end]
tlist1 = sol1.t[1:end]
EnergyErrors1=[NbodyEnergy(BigFloat.(sol1.u[j]),μ128)/E0-1 for j in 1:length(tlist1)]

ulist2 = sol2.u[1:end]
tlist2 = sol2.t[1:end]
EnergyErrors2=[NbodyEnergy(BigFloat.(sol2.u[j]),μ128)/E0-1 for j in 1:length(tlist2)]

ylimit1=-18
ylimit2=-8

p1=plot(tlist[1:end],log10.(abs.(EnergyErrors)),
    ylims=(ylimit1,ylimit2),
   xlabel="t", title="Error in energy", label="Vern9")
p2=plot(tlist1[1:end],log10.(abs.(EnergyErrors1)),
        ylims=(ylimit1,ylimit2),
    label="IRKGL16")
p2=plot!(tlist2[1:end],log10.(abs.(EnergyErrors2)),
        ylims=(ylimit1,ylimit2),
        label="IRKGl162")
plot(p1,p2,layout=2)

# %%
(Float32(maximum(abs.(EnergyErrors))),Float32(maximum(abs.(EnergyErrors1))),Float32(maximum(abs.(EnergyErrors2))))
# Out:
# (4.1384397f-14, 1.2615622f-14, 1.1071312f-14)

# %% [markdown]
# ## Global error

# %%
tspan128=[BigFloat(0.0),2*parse(BigFloat,"17.0652165601579625588917206249")]
test_sol = TestSolution(tspan128,[u0128]);

# %%
# Vern9
apr = appxtrue(sol0,test_sol)
#@show sol0[end]
#@show apr.u[end]
@show apr.errors;
# Out:
# apr.errors = Dict(:final => 1.570725999129233210462680874960864457534626126289367675781250000000000307001992e-08)

# %%
# IRGL16
apr = appxtrue(sol1,test_sol)
#@show sol1[end]
#@show apr.u[end]
@show apr.errors;
# Out:
# apr.errors = Dict(:final => 2.117799675599548293328777136962069391756813274696469306945800781250003070019921e-09)

# %%
# IRGL162
apr = appxtrue(sol2,test_sol)
#@show sol1[end]
#@show apr.u[end]
@show apr.errors
# Out:
# apr.errors = Dict(:final => 2.406004564448931753324363729678845800208364380523562431335449218750003070019921e-09)
# Dict{Symbol,BigFloat} with 1 entry:
#   :final => 2.406e-09

# %%
err1=Float32(norm(sol1.u[end]-u0128))
err2=Float32(norm(sol2.u[end]-u0128))
(err1,err2)
# Out:
# (6.6817436f-9, 7.590607f-9)

# %%
a=sol1.u[end]
b=u0128
err = [norm(a[i] - b[i]) / (norm(b[i])+1e-16) for i in 1:4]
# Out:
# 4-element Array{BigFloat,1}:
#       1.325566082117842712959952696224334873109495491156350999928444993463594181678613e-11
#  391901.2665013204237860931103606662874853521219677155231484010783208262510549132
#       6.354832065858829153310131817164958099811436480193239552186775328926702975893841e+07
#       2.048462576476834282569592682218484843921657614724641069227792904012669324540854e-09

# %%
a=sol2.u[end]
b=u0128
err = [norm(a[i] - b[i]) / norm(b[i]+1e-16) for i in 1:4]
# Out:
# 4-element Array{BigFloat,1}:
#       1.506396170333952196637249916917560198317135632728825913046422112137133023955129e-11
#  445186.4653381312401835483242661139281363867019055862461357859508257507291908809
#       7.218964875600491876577620828102090954254490429237633823067344508086439102391222e+07
#       2.327903760067921517455387192570821271085936205923241872398123623545853096500324e-09

# %% [markdown]
# ## Higher Order Algorithms

# %%
#abstols = 1.0 ./ 10.0 .^ (8:16)
#reltols = 1.0 ./ 10.0 .^ (8:16);

# %%
#setups = [
#    #Dict(:alg=>DP8())
#          Dict(:alg=>Vern9())
#          Dict(:alg=>IRKGL16())   
#          Dict(:alg=>IRKGL162())];
#wp = WorkPrecisionSet(prob,abstols,reltols,setups;appxsol=test_sol,save_everystep=false,numruns=100)
#plot(wp)
