# %% [markdown]
# # NBody15  Experiments

# %% [markdown]
# <ul id="top">
# <li><a href="#Loading-packages">
#              Loading Packages</a></li>
#
# <li><a href="#Computer-properties">
#              Computer properties</a></li>
#
# <li><a href="#Initial-value-problem:-NBody15">
#              Initial value problem: NBody15</a></li>
#
# <li><a href="#Test-solution">
#              Test solution</a></li>
#
# <li><a href="#Work-Precision-diagrams">
#              Work-Precision diagrams</a></li>
#
# <li><a href="#Save-Data">
#             Save Data</a></li>
#
# </ul>

# %% [markdown]
# ## Loading packages

# %%
using OrdinaryDiffEq,DiffEqDevTools,BenchmarkTools
using IRKGaussLegendre
using Plots,LinearAlgebra
using Dates
using JLD2, FileIO
using RecursiveArrayTools

# %%
#plotly()

# %% [markdown]
# <a href="#top">Back to the top</a>
#
# ## Computer properties

# %%
#export JULIA_NUM_THREADS=2
Threads.nthreads()
# Out:
# 1

# %%
#;cat /proc/cpuinfo # on Linux machines

# %%
using Hwloc
Hwloc.num_physical_cores()
# Out:
# 2

# %% [markdown]
# <a href="#top">Back to the top</a>
#
# ## Initial value problem: NBody-15

# %%
setprecision(BigFloat, 108);
include("../examples/Nbody.jl")
include("../examples/InitialNBody15.jl")

dt=5
t0=0.0
t1=20*dt    #20, 1000.
t1=1000.
mysaveat=1  #10
vsaveat=dt

u064,Gm64 =InitialNBody15(Float64)
lpp=Gm64
tspan64=(t0,t1)
prob64 = ODEProblem(NbodyODE!,u064,tspan64,Gm64);

u0128,Gm128=InitialNBody15(BigFloat)
tspan128=(BigFloat(t0),BigFloat(t1))
prob128 = ODEProblem(NbodyODE!,u0128,tspan128,Gm128,;lpp=lpp)

q064=u064[2,:,:]
v064=u064[1,:,:]
probdyn64 = DynamicalODEProblem(NbodyODEq!,NbodyODEv!,q064,v064,tspan64,Gm64);
prob2nd64 = SecondOrderODEProblem(NbodyODE2nd!,v064,q064,tspan64,Gm64);


q0128=u0128[2,:,:]
v0128=u0128[1,:,:]
probdyn128 = DynamicalODEProblem(NbodyODEq!,NbodyODEv!,q0128,v0128,tspan128,Gm128);
prob2nd128 = SecondOrderODEProblem(NbodyODE2nd!,v0128,q0128,tspan128,Gm128);


mysaveat=10
vsaveat=0.1;

(typeof(u064),typeof(Gm64),typeof(tspan64),typeof(u0128),typeof(Gm128),typeof(tspan128))
# Out:
# (Array{Float64,3}, Array{Float64,1}, Tuple{Float64,Int64}, Array{BigFloat,3}, Array{BigFloat,1}, Tuple{BigFloat,BigFloat})

# %% [markdown]
# <a href="#top">Back to the top</a>
#
# ## Test solution

# %%
setprecision(BigFloat, 256)
#sol =solve(prob128,Vern9(),save_everystep=false, abstol=1e-32,reltol=1e-32);
#@save "./Data/nbody15_test_solF128T1000.jld2" sol

#@load "./Data/nbody15_test_solF128T100.jld2" sol
@load "./Data/nbody15_test_solF128T1000.jld2" sol
test_sol = TestSolution(sol)
sol.destats

u0256,Gm256=InitialNBody15(BigFloat)

E0=NbodyEnergy(u0256,Gm256)

(Float32(sol.t[end]),Float32(NbodyEnergy(sol.u[end],Gm256)/E0-1))
# Out:
# DiffEqBase.DEStats
# Number of function 1 evaluations:                  98482
# Number of function 2 evaluations:                  0
# Number of W matrix evaluations:                    0
# Number of linear solves:                           0
# Number of Jacobians created:                       0
# Number of nonlinear solver iterations:             0
# Number of nonlinear solver convergence failures:   0
# Number of rootfind condition calls:                0
# Number of accepted steps:                          6155
# Number of rejected steps:                          0

# %%
ux=sol.u[end]
solx=ArrayPartition(ux[2,:,:],ux[1,:,:])
test_solx = TestSolution(tspan128,[solx]);

ux=sol.u[end]
solx2nd=ArrayPartition(ux[1,:,:],ux[2,:,:])
test_solx2nd = TestSolution(tspan128,[solx2nd]);

# %% [markdown]
# <a href="#top">Back to the top</a>
#
# ## Work-Precision diagrams (Float64)

# %%
Threads.nthreads()
# Out:
# 1

# %%
abstols = 1.0 ./ 10.0 .^ (10:19)
reltols = 1.0 ./ 10.0 .^ (10:19)

dts=16*0.866.^(0:length(reltols)-1);

# %% [markdown]
# ### Float64 (DynamicalProblem)

# %%
setups = [
          Dict(:alg=>Vern9())
          Dict(:alg=>IRKGL16(),:adaptive=>true, :mixed_precision=>false)
          Dict(:alg=>IRKGL16(),:adaptive=>false,:dts=>dts,:mixed_precision=>false) 
]
solnames = ["Vern9","IRKGL16-adaptive","IRKGL16-fixed"]
wp2 = WorkPrecisionSet(probdyn64,abstols,reltols,setups;appxsol=test_solx,save_everystep=false,numruns=1,maxiters=10^9, names=solnames)
plot(wp2)

# %% [markdown]
# ### Float64 (SecondOrderProblem)

# %%
setups = [
          Dict(:alg=>DPRKN12())   
]
solnames = ["DPRKN12"]
wp3 = WorkPrecisionSet(prob2nd64,abstols,reltols,setups;appxsol=test_solx2nd,save_everystep=false,numruns=1,maxiters=10^9,names=solnames)
plot(wp3)

# %% [markdown]
# ### Plot: OdeProblem+DynamicalProblem+SecondOrderProblem (Float64)

# %%
plot(title="DynamicalProblem Float-64")
k=1
plot!(log10.(wp2.wps[k].errors),log10.(wp2.wps[k].times), seriestype=:scatter, label="Vern9", color="blue")
plot!(log10.(wp2.wps[k].errors),log10.(wp2.wps[k].times), label="",lw=2, color="blue")
# 
k=2
plot!(log10.(wp2.wps[k].errors),log10.(wp2.wps[k].times), seriestype=:scatter, label="IRKGL16",color="red")
plot!(log10.(wp2.wps[k].errors),log10.(wp2.wps[k].times), label="", lw=2, color="red")
#
k=3
plot!(log10.(wp2.wps[k].errors),log10.(wp2.wps[k].times), seriestype=:scatter, label="IRKGL16-fix",color="orange")
plot!(log10.(wp2.wps[k].errors),log10.(wp2.wps[k].times), label="", lw=2, color="orange")
#
k=1
plot!(log10.(wp3.wps[k].errors),log10.(wp3.wps[k].times), seriestype=:scatter, label="DPRKN12",color="green")
plot!(log10.(wp3.wps[k].errors),log10.(wp3.wps[k].times), label="", lw=2, color="green")

# %% [markdown]
# <a href="#top">Back to the top</a>
#
# ## Work-Precision diagrams (Float128)

# %%
now()
# Out:
# 2020-06-18T22:20:28.491

# %%
setprecision(BigFloat, 108)
abstols = 1.0 ./ 10.0 .^ (12:30)
reltols = 1.0 ./ 10.0 .^ (12:30)

dts=16*0.866.^(0:length(reltols)-1);

# %% [markdown]
# ### Float128 (OdeProblem)

# %%
setups = [ Dict(:alg=>Vern9())
           Dict(:alg=>IRKGL16(),:adaptive=>true,:mixed_precision=>false) 
           Dict(:alg=>IRKGL16(),:adaptive=>true,:mixed_precision=>false,:threading=>true) 
           Dict(:alg=>IRKGL16(),:adaptive=>true,:mixed_precision=>true,:low_prec_type=>Float64)
           Dict(:alg=>IRKGL16(),:adaptive=>true,:mixed_precision=>true,:low_prec_type=>Float64,:threading=>true)
           Dict(:alg=>IRKGL16(),:adaptive=>false,:dts=>dts,:mixed_precision=>false) 
           Dict(:alg=>IRKGL16(),:adaptive=>false,:dts=>dts,:mixed_precision=>false,:threading=>true) 
           Dict(:alg=>IRKGL16(),:adaptive=>false,:dts=>dts,:mixed_precision=>true,:low_prec_type=>Float64)
           Dict(:alg=>IRKGL16(),:adaptive=>false,:dts=>dts,:mixed_precision=>true,:low_prec_type=>Float64,:threading=>true)
]
solnames = ["Vern9","IRKGL16-adaptive","IRKGL16-adaptive/threads","IRKGL16-adaptive/Mix","IRKGL16-adaptive/Mix/thread","IRKGL16-fix","IRKGL16-fix/threads","IRKGL16-fix/Mix","IRKGL16-fix/Mix/thread"]
wp11 = WorkPrecisionSet(prob128,abstols,reltols,setups;appxsol=test_sol,save_everystep=false,numruns=1,maxiters=10^9)
plot(wp11)
# Out:
# TaskFailedException:
# InterruptException:
# Stacktrace:
#  [1] ^(::BigFloat, ::BigFloat) at ./mpfr.jl:592
#  [2] ^ at ./promotion.jl:343 [inlined]
#  [3] NbodyODE!(::Array{BigFloat,3}, ::Array{BigFloat,3}, ::Array{BigFloat,1}, ::BigFloat) at /home/joseba/Mahaigaina/PIC/PIC-2019/ikerketak/Julia Con/Softwarea/7-IRK/IRKGaussLegendre/examples/Nbody.jl:56
#  [4] (::ODEFunction{true,typeof(NbodyODE!),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing})(::Array{BigFloat,3}, ::Vararg{Any,N} where N) at /home/joseba/.julia/packages/DiffEqBase/ytZvl/src/diffeqfunction.jl:248
#  [5] macro expansion at /home/joseba/Mahaigaina/PIC/PIC-2019/ikerketak/Julia Con/Softwarea/7-IRK/IRKGaussLegendre/src/IRKGL16Solver.jl:457 [inlined]
#  [6] (::IRKGaussLegendre.var"#65#threadsfor_fun#7"{Array{BigFloat,3},ODEFunction{true,typeof(NbodyODE!),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{BigFloat,1},Array{Array{BigFloat,3},1},Array{Array{BigFloat,3},1},Array{Array{BigFloat,3},1},Array{Array{BigFloat,3},1},Array{Array{BigFloat,3},1},Array{Bool,1},Array{BigFloat,1},Array{Int64,1},BigFloat,UnitRange{Int64}})(::Bool) at ./threadingconstructs.jl:61
#  [7] (::IRKGaussLegendre.var"#65#threadsfor_fun#7"{Array{BigFloat,3},ODEFunction{true,typeof(NbodyODE!),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{BigFloat,1},Array{Array{BigFloat,3},1},Array{Array{BigFloat,3},1},Array{Array{BigFloat,3},1},Array{Array{BigFloat,3},1},Array{Array{BigFloat,3},1},Array{Bool,1},Array{BigFloat,1},Array{Int64,1},BigFloat,UnitRange{Int64}})() at ./threadingconstructs.jl:28
#
# Stacktrace:
#  [1] wait(::Task) at ./task.jl:267
#  [2] macro expansion at ./threadingconstructs.jl:69 [inlined]
#  [3] IRKstep_fixed!(::Int64, ::Int64, ::Array{BigFloat,1}, ::Array{BigFloat,3}, ::Array{BigFloat,3}, ::ODEProblem{Array{BigFloat,3},Tuple{BigFloat,BigFloat},true,Array{BigFloat,1},ODEFunction{true,typeof(NbodyODE!),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Symbol,Array{Float64,1},Tuple{Symbol},NamedTuple{(:lpp,),Tuple{Array{Float64,1}}}},DiffEqBase.StandardODEProblem}, ::Array{BigFloat,1}, ::tcoeffs{BigFloat}, ::IRKGaussLegendre.tcache{Array{BigFloat,3},BigFloat,Array{Float64,3},Float64}, ::Int64, ::Bool, ::BigFloat, ::BigFloat, ::Bool) at /home/joseba/Mahaigaina/PIC/PIC-2019/ikerketak/Julia Con/Softwarea/7-IRK/IRKGaussLegendre/src/IRKGL16Solver.jl:440
#  [4] IRKStep!(::Int64, ::Int64, ::Array{BigFloat,1}, ::Array{BigFloat,3}, ::Array{BigFloat,3}, ::ODEProblem{Array{BigFloat,3},Tuple{BigFloat,BigFloat},true,Array{BigFloat,1},ODEFunction{true,typeof(NbodyODE!),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Symbol,Array{Float64,1},Tuple{Symbol},NamedTuple{(:lpp,),Tuple{Array{Float64,1}}}},DiffEqBase.StandardODEProblem}, ::Array{BigFloat,1}, ::tcoeffs{BigFloat}, ::IRKGaussLegendre.tcache{Array{BigFloat,3},BigFloat,Array{Float64,3},Float64}, ::Int64, ::Int64, ::Bool, ::BigFloat, ::BigFloat, ::Bool, ::Bool, ::Type{T} where T) at /home/joseba/Mahaigaina/PIC/PIC-2019/ikerketak/Julia Con/Softwarea/7-IRK/IRKGaussLegendre/src/IRKGL16Solver.jl:331
#  [5] __solve(::ODEProblem{Array{BigFloat,3},Tuple{BigFloat,BigFloat},true,Array{BigFloat,1},ODEFunction{true,typeof(NbodyODE!),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Symbol,Array{Float64,1},Tuple{Symbol},NamedTuple{(:lpp,),Tuple{Array{Float64,1}}}},DiffEqBase.StandardODEProblem}, ::IRKGL16, ::Array{Any,1}, ::Vararg{Any,N} where N; dt::Float64, saveat::Int64, maxiter::Int64, maxtrials::Int64, save_everystep::Bool, initial_interp::Bool, adaptive::Bool, reltol::Float64, abstol::Float64, myoutputs::Bool, mixed_precision::Bool, low_prec_type::Type{T} where T, kwargs::Base.Iterators.Pairs{Symbol,Any,NTuple{6,Symbol},NamedTuple{(:lpp, :timeseries_errors, :dense_errors, :maxiters, :alg, :dts),Tuple{Array{Float64,1},Bool,Bool,Int64,IRKGL16,Array{Float64,1}}}}) at /home/joseba/Mahaigaina/PIC/PIC-2019/ikerketak/Julia Con/Softwarea/7-IRK/IRKGaussLegendre/src/IRKGL16Solver.jl:262
#  [6] (::DiffEqBase.var"#462#463"{ODEProblem{Array{BigFloat,3},Tuple{BigFloat,BigFloat},true,Array{BigFloat,1},ODEFunction{true,typeof(NbodyODE!),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Symbol,Array{Float64,1},Tuple{Symbol},NamedTuple{(:lpp,),Tuple{Array{Float64,1}}}},DiffEqBase.StandardODEProblem},Tuple{IRKGL16,Array{Any,1},Array{Any,1},Nothing}})() at /home/joseba/.julia/packages/DiffEqBase/ytZvl/src/solve.jl:49
#  [7] maybe_with_logger(::DiffEqBase.var"#462#463"{ODEProblem{Array{BigFloat,3},Tuple{BigFloat,BigFloat},true,Array{BigFloat,1},ODEFunction{true,typeof(NbodyODE!),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Symbol,Array{Float64,1},Tuple{Symbol},NamedTuple{(:lpp,),Tuple{Array{Float64,1}}}},DiffEqBase.StandardODEProblem},Tuple{IRKGL16,Array{Any,1},Array{Any,1},Nothing}}, ::Nothing) at /home/joseba/.julia/packages/DiffEqBase/ytZvl/src/utils.jl:259
#  [8] solve_call(::ODEProblem{Array{BigFloat,3},Tuple{BigFloat,BigFloat},true,Array{BigFloat,1},ODEFunction{true,typeof(NbodyODE!),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Symbol,Array{Float64,1},Tuple{Symbol},NamedTuple{(:lpp,),Tuple{Array{Float64,1}}}},DiffEqBase.StandardODEProblem}, ::IRKGL16, ::Vararg{Any,N} where N; merge_callbacks::Bool, kwargs::Base.Iterators.Pairs{Symbol,Any,NTuple{11,Symbol},NamedTuple{(:abstol, :reltol, :dt, :timeseries_errors, :dense_errors, :save_everystep, :maxiters, :alg, :adaptive, :mixed_precision, :dts),Tuple{Float64,Float64,Float64,Bool,Bool,Bool,Int64,IRKGL16,Bool,Bool,Array{Float64,1}}}}) at /home/joseba/.julia/packages/DiffEqBase/ytZvl/src/solve.jl:48
#  [9] #solve#464 at /home/joseba/.julia/packages/DiffEqBase/ytZvl/src/solve.jl:66 [inlined]
#  [10] macro expansion at ./util.jl:234 [inlined]
#  [11] (::DiffEqDevTools.var"#17#20"{Int64,Array{Float64,1},ODEProblem{Array{BigFloat,3},Tuple{BigFloat,BigFloat},true,Array{BigFloat,1},ODEFunction{true,typeof(NbodyODE!),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Symbol,Array{Float64,1},Tuple{Symbol},NamedTuple{(:lpp,),Tuple{Array{Float64,1}}}},DiffEqBase.StandardODEProblem},IRKGL16,ODESolution{Any,4,Array{Any,1},Nothing,Nothing,Array{Any,1},Nothing,ODEProblem{Array{BigFloat,3},Tuple{BigFloat,BigFloat},true,Array{BigFloat,1},ODEFunction{true,typeof(NbodyODE!),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Symbol,Array{Float64,1},Tuple{Symbol},NamedTuple{(:lpp,),Tuple{Array{Float64,1}}}},DiffEqBase.StandardODEProblem},IRKGL16,DiffEqBase.LinearInterpolation{Array{Any,1},Array{Any,1}},DiffEqBase.DEStats},Array{Float64,1},Array{Float64,1},Base.Iterators.Pairs{Symbol,Any,NTuple{6,Symbol},NamedTuple{(:save_everystep, :maxiters, :alg, :adaptive, :mixed_precision, :dts),Tuple{Bool,Int64,IRKGL16,Bool,Bool,Array{Float64,1}}}}})() at /home/joseba/.julia/packages/DiffEqDevTools/nDVct/src/benchmark.jl:213
#  [12] WorkPrecision(::ODEProblem{Array{BigFloat,3},Tuple{BigFloat,BigFloat},true,Array{BigFloat,1},ODEFunction{true,typeof(NbodyODE!),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Symbol,Array{Float64,1},Tuple{Symbol},NamedTuple{(:lpp,),Tuple{Array{Float64,1}}}},DiffEqBase.StandardODEProblem}, ::IRKGL16, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}; name::String, appxsol::TestSolution{Nothing,0,true,Nothing,Nothing,ODESolution{BigFloat,4,Array{Array{BigFloat,3},1},Nothing,Nothing,Array{BigFloat,1},Array{Array{Array{BigFloat,3},1},1},ODEProblem{Array{BigFloat,3},Tuple{BigFloat,BigFloat},true,Array{BigFloat,1},ODEFunction{true,typeof(NbodyODE!),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Symbol,Array{Float64,1},Tuple{Symbol},NamedTuple{(:lpp,),Tuple{Array{Float64,1}}}},DiffEqBase.StandardODEProblem},Vern9,OrdinaryDiffEq.InterpolationData{ODEFunction{true,typeof(NbodyODE!),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{BigFloat,3},1},Array{BigFloat,1},Array{Array{Array{BigFloat,3},1},1},OrdinaryDiffEq.Vern9Cache{Array{BigFloat,3},Array{BigFloat,3},Array{BigFloat,3},OrdinaryDiffEq.Vern9Tableau{BigFloat,BigFloat}}},DiffEqBase.DEStats}}, error_estimate::Symbol, numruns::Int64, seconds::Int64, kwargs::Base.Iterators.Pairs{Symbol,Any,NTuple{6,Symbol},NamedTuple{(:save_everystep, :maxiters, :alg, :adaptive, :mixed_precision, :dts),Tuple{Bool,Int64,IRKGL16,Bool,Bool,Array{Float64,1}}}}) at /home/joseba/.julia/packages/DiffEqDevTools/nDVct/src/benchmark.jl:221
#  [13] WorkPrecisionSet(::ODEProblem{Array{BigFloat,3},Tuple{BigFloat,BigFloat},true,Array{BigFloat,1},ODEFunction{true,typeof(NbodyODE!),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Symbol,Array{Float64,1},Tuple{Symbol},NamedTuple{(:lpp,),Tuple{Array{Float64,1}}}},DiffEqBase.StandardODEProblem}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Dict{Symbol,V} where V,1}; print_names::Bool, names::Nothing, appxsol::TestSolution{Nothing,0,true,Nothing,Nothing,ODESolution{BigFloat,4,Array{Array{BigFloat,3},1},Nothing,Nothing,Array{BigFloat,1},Array{Array{Array{BigFloat,3},1},1},ODEProblem{Array{BigFloat,3},Tuple{BigFloat,BigFloat},true,Array{BigFloat,1},ODEFunction{true,typeof(NbodyODE!),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Symbol,Array{Float64,1},Tuple{Symbol},NamedTuple{(:lpp,),Tuple{Array{Float64,1}}}},DiffEqBase.StandardODEProblem},Vern9,OrdinaryDiffEq.InterpolationData{ODEFunction{true,typeof(NbodyODE!),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{BigFloat,3},1},Array{BigFloat,1},Array{Array{Array{BigFloat,3},1},1},OrdinaryDiffEq.Vern9Cache{Array{BigFloat,3},Array{BigFloat,3},Array{BigFloat,3},OrdinaryDiffEq.Vern9Tableau{BigFloat,BigFloat}}},DiffEqBase.DEStats}}, error_estimate::Symbol, test_dt::Nothing, kwargs::Base.Iterators.Pairs{Symbol,Integer,Tuple{Symbol,Symbol,Symbol},NamedTuple{(:save_everystep, :numruns, :maxiters),Tuple{Bool,Int64,Int64}}}) at /home/joseba/.julia/packages/DiffEqDevTools/nDVct/src/benchmark.jl:248
#  [14] top-level scope at In[72]:7

# %% [markdown]
# ### Float128 (DynamicalProblem)

# %%
setups = [
          Dict(:alg=>Vern9())
          Dict(:alg=>IRKGL16(),:adaptive=>true,:mixed_precision=>false)
          Dict(:alg=>IRKGL16(),:adaptive=>true,:mixed_precision=>false, :threading=>true)
          Dict(:alg=>IRKGL16(),:adaptive=>false,:dts=>dts,:mixed_precision=>false) 
          Dict(:alg=>IRKGL16(),:adaptive=>false,:dts=>dts,:mixed_precision=>false,:threading=>true) 
]
solnames = ["Vern9", "IRKGL16-adaptive", "IRKGL16-fix", "IRKGL16-fix/thread"]
wp12 = WorkPrecisionSet(probdyn128,abstols,reltols,setups;appxsol=test_solx,save_everystep=false,numruns=1,maxiters=10^9,name=solnames)
plot(wp12)

# %% [markdown]
# ### Float128 (SecondOrderProblem)

# %%
setups = [
          Dict(:alg=>DPRKN12())   
]
solname=["DPRKN12"]
wp13 = WorkPrecisionSet(prob2nd128,abstols,reltols,setups;appxsol=test_solx2nd,save_everystep=false,numruns=1,maxiters=10^9, names=solname)
plot(wp13)

# %% [markdown]
# ### Plot: OdeProblem+DynamicalProblem+SecondOrderProblem

# %%
k=1
plot(log10.(wp11.wps[k].errors),log10.(wp11.wps[k].times), seriestype=:scatter, label="Vern9 (OdeProblem)")
plot!(log10.(wp11.wps[k].errors),log10.(wp11.wps[k].times), label="")
# 
k=1
plot!(log10.(wp12.wps[k].errors),log10.(wp12.wps[k].times), seriestype=:scatter, label="Vern9 (DynamicProblem)")
plot!(log10.(wp12.wps[k].errors),log10.(wp12.wps[k].times), label="")

# %%
k=9
plot(log10.(wp11.wps[k].errors),log10.(wp11.wps[k].times), seriestype=:scatter, label="IRKGL16 (OdeProblem)", color="red")
plot!(log10.(wp11.wps[k].errors),log10.(wp11.wps[k].times), label="", color="red")
#
k=5
plot!(log10.(wp12.wps[k].errors),log10.(wp12.wps[k].times), seriestype=:scatter, label="IRKGL16 (DynamicProblem)",  color="green")
plot!(log10.(wp12.wps[k].errors),log10.(wp12.wps[k].times), label="", color="green")

# %%
k=1
plot(log10.(wp12.wps[k].errors),log10.(wp12.wps[k].times), seriestype=:scatter, label="Vern9 (DynamicProblem)", color="blue")
plot!(log10.(wp12.wps[k].errors),log10.(wp12.wps[k].times), label="",color="blue")
#
k=9
plot!(log10.(wp11.wps[k].errors),log10.(wp11.wps[k].times), seriestype=:scatter, label="IRKGL16-MIX (OdeProblem)", color="red")
plot!(log10.(wp11.wps[k].errors),log10.(wp11.wps[k].times), label="", color="red")
#
k=1
plot!(log10.(wp13.wps[k].errors),log10.(wp13.wps[k].times), seriestype=:scatter, label="DPRKN12 (2OdeProblem)", color="green")
plot!(log10.(wp13.wps[k].errors),log10.(wp13.wps[k].times), label="", color="green")

# %% [markdown]
# <a href="#top">Back to the top</a>

# %% [markdown]
# ### Save Data

# %%
 Float64 experiments
@save "./Data/output/OutNBody15_wp2.jld2" wp2
@save "./Data/output/OutNBody15_wp3.jld2" wp3
# Float128 experiments
@save "./Data/output/OutNBody15_wp11.jld2" wp11
@save "./Data/output/OutNBody15_wp12.jld2" wp12
@save "./Data/output/OutNBody15_wp13.jld2" wp13

# %%
# Float64 experiments
#@load "./Data/output/OutNBody15_wp2.jld2" wp2
#@load "./Data/output/OutNBody15_wp3.jld2" wp3
# Float128 experiments
#@load "./Data/output/OutNBody15_wp11.jld2" wp11
#@load "./Data/output/OutNBody15_wp12.jld2" wp12
#@load "./Data/output/OutNBody15_wp13.jld2" wp13

# %%
now()
# Out:
# 2020-06-18T22:23:06.376
